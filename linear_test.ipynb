# %%
import os
import sys

sys.path.append(os.getcwd())
sys.path.append("/home/joaobrasil/Documents/Python/ml-from-scratch")
import linear_models

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
list_tips = np.array(tips['tip'].to_list())
list_bill = np.array(tips['total_bill'].to_list())

# %%
b0, b1 = linear_models.linear_regression_closed_form(list_bill, list_bill)

# %%
b0 + b1 * tips['tip'].iloc[4]
# Out:
# np.float64(3.6100000000000025)
